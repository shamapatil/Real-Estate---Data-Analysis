# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
house = pd.read_csv("C:\\Users\\shama\\Documents\\excelr_project\\house1_data.csv",index_col=0)
house
# Out:
#                                           Location   Price_per_sqft  \
# 0                 2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1            3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2           11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3                3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4                2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                            ...              ...
# 3733         Residential land / Plot in Bidrahalli   ₹ 2,100/sq.ft.
# 3734  Residential land / Plot in Bannerghatta Road   ₹ 1,590/sq.ft.
# 3735         Residential land / Plot in banergatta   ₹ 3,000/sq.ft.
# 3736                    2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737              3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                   Total_sqft                       Area  \
# 0        959 sq.ft. (89 sq.m.) Built-up Area   (89 sq.m.) Built-up Area
# ...

# %%
cols=house.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(house[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
house.isnull().sum()
# Out:
# Location            0
# Price_per_sqft      0
# Total_sqft          0
# Area                0
# BHK               998
# Price               0
# dtype: int64

# %%
data = house.dropna()

# %%
data
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
new_data = data.drop_duplicates()

# %%
new_data
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
print("Cleaned dataset shape = ",new_data.shape)
# Out:
# Cleaned dataset shape =  (1658, 6)

# %% [markdown]
# # Exploratory Data Analysis

# %%
new_data[new_data['Price'] == 'price on req'].count()
# Out:
# Location          0
# Price_per_sqft    0
# Total_sqft        0
# Area              0
# BHK               0
# Price             0
# dtype: int64

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1658 entries, 0 to 3737
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        1658 non-null   object
#  1   Price_per_sqft  1658 non-null   object
#  2   Total_sqft      1658 non-null   object
#  3   Area            1658 non-null   object
#  4   BHK             1658 non-null   object
#  5   Price           1658 non-null   object
# dtypes: object(6)
# memory usage: 90.7+ KB

# %%
new_data['BHK'].unique()
# Out:
# array(['2 BHK2 Baths', '3 BHK3 Baths', '11 BHK11 Baths', '5 BHK6 Baths',
#        '5 BHK4 Baths', '3 BHK2 Baths', '12 BHK12 Baths', '6 BHK7 Baths',
#        '9 BHK8 Baths', '4 BHK5 Baths', '6 BHK5 Baths', '1 BHK1 Bath',
#        '3 BHK4 Baths', '5 BHK5 Baths', '4 BHK2 Baths', '9 BHK9 Baths',
#        '4 BHK4 Baths', '6 BHK6 Baths', '5 BHK8 Baths', '14 BHK13 Baths',
#        '5 BHK14 Baths', '2 BHK1 Bath', '3 BHK5 Baths', '7 BHK9 Baths',
#        '12 BHK8 Baths', '8 BHK7 Baths', '4 BHK3 Baths', '13 BHK12 Baths',
#        '7 BHK8 Baths', '6 BHK3 Baths', '14 BHK14 Baths', '7 BHK7 Baths',
#        '2 BHK3 Baths', '6 BHK4 Baths', '11 BHK10 Baths', '7 BHK6 Baths',
#        '8 BHK10 Baths', '10 BHK10 Baths', '5 BHK3 Baths',
#        '32 BHK32 Baths', '4 BHK6 Baths', '1 BHK2 Baths', '14 BHK15 Baths',
#        '11 BHK8 Baths', '13 BHK10 Baths', '9 BHK6 Baths', '6 BHK8 Baths',
#        '10 BHK3 Baths', '13 BHK13 Baths', '3 BHK1 Bath', '10 BHK6 Baths',
# ...

# %%
new_data.describe()
# Out:
#                                   Location  Price_per_sqft  \
# count                                 1658            1658
# unique                                1103            1216
# top     2 BHK Apartment in Electronic City  ₹ 5,000/sq.ft.
# freq                                    22              22
#
#                                 Total_sqft                   Area  \
# count                                 1658                   1658
# unique                                 934                    540
# top     1,200 sq.ft. (111 sq.m.) Plot Area  (111 sq.m.) Plot Area
# freq                                    96                     98
#
#                  BHK                    Price
# count           1658                     1658
# unique            62                     1511
# top     2 BHK2 Baths  ₹ 1.2 Cr₹ 10,000/sq.ft.
# freq             669                        9

# %%
plt.figure(figsize=(40,30))
sns.countplot(new_data['BHK'])
plt.show()
# Out:
# C:\Users\shama\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
new_data
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
new_data[['curr','price','amt','sq']] = new_data.Price.str.split(expand=True)

# %%
new_data
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
new_data.drop(['Price','curr','sq'],axis=1)
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
new_data[['bedroom','baths']] = new_data.BHK.str.split('BHK',expand=True)

# %%
new_data
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
clean = new_data.drop(['BHK','Price','curr','sq'],axis=1)

# %%
clean
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
 clean[['cur','rs']] = clean.amt.str.split('₹',expand=True)

# %%
clean
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
clean2 = clean.drop(['rs','amt'],axis=1)

# %%
clean2
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
clean2['Price'] = clean2['price']+clean2['cur']

# %%
clean2
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
clean3 = clean2.drop(['cur','price'],axis=1)

# %%
clean3
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
clean3[['a','b','c','d','e','f','g']]=clean3.Total_sqft.str.split(expand=True)

# %%
clean3
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                         Total_sqft  \
# 0              959 sq.ft. (89 sq.m.) Built-up Area
# 1           2,280 sq.ft. (212 sq.m.) Built-up Area
# 2               1,200 sq.ft. (111 sq.m.) Plot Area
# ...

# %%
clean4 = clean3.drop(['Total_sqft','c','d','g'],axis=1)

# %%
clean4
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                  Area bedroom     baths   Price      a  \
# 0            (89 sq.m.) Built-up Area      2    2 Baths     42L    959
# 1           (212 sq.m.) Built-up Area      3    3 Baths  2.25Cr  2,280
# ...

# %%
clean4['Total_sqft'] = clean4['a']+clean4['b']

# %%
clean4
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                  Area bedroom     baths   Price      a  \
# 0            (89 sq.m.) Built-up Area      2    2 Baths     42L    959
# 1           (212 sq.m.) Built-up Area      3    3 Baths  2.25Cr  2,280
# ...

# %%
clean4['Area_Type'] = clean4['e']+clean4['f']

# %%
clean4
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                  Area bedroom     baths   Price      a  \
# 0            (89 sq.m.) Built-up Area      2    2 Baths     42L    959
# 1           (212 sq.m.) Built-up Area      3    3 Baths  2.25Cr  2,280
# ...

# %%
clean5 = clean4.drop(['a','b','e','f'],axis=1)

# %%
clean5
# Out:
#                                     Location   Price_per_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.
# ...                                      ...              ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.
#
#                                  Area bedroom     baths   Price   Total_sqft  \
# 0            (89 sq.m.) Built-up Area      2    2 Baths     42L    959sq.ft.
# ...

# %%
clean6=clean5.drop(['Area'],axis=1)
clean6
# Out:
#                                     Location   Price_per_sqft bedroom  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.      2
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.      3
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.     11
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.      3
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.      2
# ...                                      ...              ...     ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.      3
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.      2
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.      2
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.      2
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.      3
#
#          baths   Price   Total_sqft      Area_Type
# 0      2 Baths     42L    959sq.ft.   Built-upArea
# ...

# %%
clean6[['a','b']]=clean6.Price_per_sqft.str.split('/',expand=True)

# %%
clean6
# Out:
#                                     Location   Price_per_sqft bedroom  \
# 0           2 BHK Apartment in Maruthi Nagar   ₹ 4,171/sq.ft.      2
# 1      3 BHK Apartment in 3rd Phase JP Nagar   ₹ 9,868/sq.ft.      3
# 2     11 Bedroom House in 8th Phase JP Nagar  ₹ 15,000/sq.ft.     11
# 3          3 BHK Apartment in CV Raman Nagar  ₹ 10,507/sq.ft.      3
# 4          2 BHK Apartment in CV Raman Nagar   ₹ 5,579/sq.ft.      2
# ...                                      ...              ...     ...
# 3728          3 BHK Apartment in Nehru Nagar   ₹ 5,800/sq.ft.      3
# 3729        2 BHK Apartment in Sarjapur Road   ₹ 5,243/sq.ft.      2
# 3730   2 BHK Apartment in Addischetan Layout   ₹ 5,800/sq.ft.      2
# 3736              2 Bedroom House in Kengeri   ₹ 8,923/sq.ft.      2
# 3737        3 Bedroom House in Kaggadasapura  ₹ 13,888/sq.ft.      3
#
#          baths   Price   Total_sqft      Area_Type         a       b
# ...

# %%
clean7=clean6.drop(['b','Price_per_sqft'],axis=1)
clean7
# Out:
#                                     Location bedroom     baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar      2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar      3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar     11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar      3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar      2    2 Baths     65L
# ...                                      ...     ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar      3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road      2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout      2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri      2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura      3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type         a
# 0       959sq.ft.   Built-upArea   ₹ 4,171
# ...

# %%
clean7[['c','d']]=clean7.a.str.split('₹',expand=True)

# %%
clean7
# Out:
#                                     Location bedroom     baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar      2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar      3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar     11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar      3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar      2    2 Baths     65L
# ...                                      ...     ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar      3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road      2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout      2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri      2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura      3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type         a c         d
# 0       959sq.ft.   Built-upArea   ₹ 4,171       4,171
# ...

# %%
clean8=clean7.drop(['a','c'],axis=1)
clean8
# Out:
#                                     Location bedroom     baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar      2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar      3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar     11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar      3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar      2    2 Baths     65L
# ...                                      ...     ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar      3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road      2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout      2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri      2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura      3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type        d
# 0       959sq.ft.   Built-upArea    4,171
# ...

# %%
clean8.rename(columns = {'d':'Price_per_sqft','bedroom':'Bedrooms','baths':'Baths'},inplace=True)

# %%
clean8
# Out:
#                                     Location Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths     65L
# ...                                      ...      ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type Price_per_sqft
# 0       959sq.ft.   Built-upArea          4,171
# ...

# %%
clean8[['a','b']]=clean8.Price_per_sqft.str.split(',',expand=True)
clean8
# Out:
#                                     Location Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths     65L
# ...                                      ...      ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type Price_per_sqft    a    b
# ...

# %%
clean9=clean8.drop(['Price_per_sqft'],axis=1)
clean9
# Out:
#                                     Location Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths     65L
# ...                                      ...      ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type    a    b
# 0       959sq.ft.   Built-upArea    4  171
# ...

# %%
clean9['Price_per_sqft'] = clean9['a']+clean9['b']
clean9
# Out:
#                                     Location Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths     65L
# ...                                      ...      ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type    a    b Price_per_sqft
# ...

# %%
clean9['Price_per_sqft']=pd.to_numeric(clean9['Price_per_sqft'],errors='coerce')

# %%
clean9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1658 entries, 0 to 3737
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        1658 non-null   object
#  1   Bedrooms        1658 non-null   object
#  2   Baths           1657 non-null   object
#  3   Price           1658 non-null   object
#  4   Total_sqft      1658 non-null   object
#  5   Area_Type       1658 non-null   object
#  6   a               1658 non-null   object
#  7   b               1643 non-null   object
#  8   Price_per_sqft  1643 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 129.5+ KB

# %%
clean10=clean9.drop(['a','b'],axis=1)
clean10
# Out:
#                                     Location Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths     65L
# ...                                      ...      ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3    2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2    2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2    2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2     1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3    4 Baths  1.25Cr
#
#        Total_sqft      Area_Type  Price_per_sqft
# 0       959sq.ft.   Built-upArea          4171.0
# ...

# %%
clean10['Bedrooms']=pd.to_numeric(clean10['Bedrooms'],errors='coerce')

# %%
clean10[['Bathrooms','b']]=clean10.Baths.str.split(' ',expand=True)
clean10
# Out:
#                                     Location  Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2.0   2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3.0   3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11.0  11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3.0   3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2.0   2 Baths     65L
# ...                                      ...       ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3.0   2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2.0   2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2.0   2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2.0    1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3.0   4 Baths  1.25Cr
#
#        Total_sqft      Area_Type  Price_per_sqft   a      b Bathrooms
# ...

# %%
clean11=clean10.drop(['a','b'],axis=1)
clean11
# Out:
#                                     Location  Bedrooms     Baths   Price  \
# 0           2 BHK Apartment in Maruthi Nagar       2.0   2 Baths     42L
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3.0   3 Baths  2.25Cr
# 2     11 Bedroom House in 8th Phase JP Nagar      11.0  11 Baths   1.8Cr
# 3          3 BHK Apartment in CV Raman Nagar       3.0   3 Baths   2.3Cr
# 4          2 BHK Apartment in CV Raman Nagar       2.0   2 Baths     65L
# ...                                      ...       ...       ...     ...
# 3728          3 BHK Apartment in Nehru Nagar       3.0   2 Baths  73.95L
# 3729        2 BHK Apartment in Sarjapur Road       2.0   2 Baths     55L
# 3730   2 BHK Apartment in Addischetan Layout       2.0   2 Baths     58L
# 3736              2 Bedroom House in Kengeri       2.0    1 Bath     58L
# 3737        3 Bedroom House in Kaggadasapura       3.0   4 Baths  1.25Cr
#
#        Total_sqft      Area_Type  Price_per_sqft Bathrooms
# ...

# %%
clean11['Bathrooms']=pd.to_numeric(clean11['Bathrooms'],errors='coerce')

# %%
clean11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1658 entries, 0 to 3737
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        1658 non-null   object
#  1   Bedrooms        1657 non-null   float64
#  2   Baths           1657 non-null   object
#  3   Price           1658 non-null   object
#  4   Total_sqft      1658 non-null   object
#  5   Area_Type       1658 non-null   object
#  6   Price_per_sqft  1643 non-null   float64
#  7   Bathrooms       1657 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 116.6+ KB

# %%
cleaned=clean11.loc[:,['Location','Bedrooms','Bathrooms','Total_sqft','Price_per_sqft','Price','Area_Type']]

# %%
cleaned
# Out:
#                                     Location  Bedrooms  Bathrooms  \
# 0           2 BHK Apartment in Maruthi Nagar       2.0        2.0
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3.0        3.0
# 2     11 Bedroom House in 8th Phase JP Nagar      11.0       11.0
# 3          3 BHK Apartment in CV Raman Nagar       3.0        3.0
# 4          2 BHK Apartment in CV Raman Nagar       2.0        2.0
# ...                                      ...       ...        ...
# 3728          3 BHK Apartment in Nehru Nagar       3.0        2.0
# 3729        2 BHK Apartment in Sarjapur Road       2.0        2.0
# 3730   2 BHK Apartment in Addischetan Layout       2.0        2.0
# 3736              2 Bedroom House in Kengeri       2.0        1.0
# 3737        3 Bedroom House in Kaggadasapura       3.0        4.0
#
#        Total_sqft  Price_per_sqft   Price      Area_Type
# 0       959sq.ft.          4171.0     42L   Built-upArea
# 1     2,280sq.ft.          9868.0  2.25Cr   Built-upArea
# ...

# %%
cleaned.to_csv("property_info")

# %%
house=pd.read_csv("property_data",index_col=0)

# %%
house=house.reset_index()

# %%
house.drop(['index'],axis=1)
# Out:
#                                     Location Bedrooms     Baths   Total_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths    959sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2,280sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths  1,200sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths  2,189sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths  1,165sq.ft.
# ...                                      ...      ...       ...          ...
# 1653          3 BHK Apartment in Nehru Nagar       3    2 Baths  1,275sq.ft.
# 1654        2 BHK Apartment in Sarjapur Road       2    2 Baths  1,049sq.ft.
# 1655   2 BHK Apartment in Addischetan Layout       2    2 Baths  1,000sq.ft.
# 1656              2 Bedroom House in Kengeri       2     1 Bath    650sq.ft.
# 1657        3 Bedroom House in Kaggadasapura       3    4 Baths    900sq.ft.
#
#      Price_per_sqft   Price      Area_Type
# ...

# %%
house.to_csv("99acres_data")

# %%
house = pd.read_csv("C:\\Users\\shama\\Documents\\excelr_project\\99acres_data.csv",index_col=0)
house
# Out:
#       index                                Location Bedrooms     Baths  \
# 0         0        2 BHK Apartment in Maruthi Nagar       2    2 Baths
# 1         1   3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths
# 2         2  11 Bedroom House in 8th Phase JP Nagar      11   11 Baths
# 3         3       3 BHK Apartment in CV Raman Nagar       3    3 Baths
# 4         4       2 BHK Apartment in CV Raman Nagar       2    2 Baths
# ...     ...                                     ...      ...       ...
# 1653   3728          3 BHK Apartment in Nehru Nagar       3    2 Baths
# 1654   3729        2 BHK Apartment in Sarjapur Road       2    2 Baths
# 1655   3730   2 BHK Apartment in Addischetan Layout       2    2 Baths
# 1656   3736              2 Bedroom House in Kengeri       2     1 Bath
# 1657   3737        3 Bedroom House in Kaggadasapura       3    4 Baths
#
#        Total_sqft Price_per_sqft   Price      Area_Type
# 0       959sq.ft.          4,171     42L   Built-upArea
# ...

# %%
house1[house1['Baths'].isna()]
# Out:
#                 Location  Bedrooms Baths   Total_sqft  Price_per_sqft  Price  \
# 782  House in AGS Layout  11 Baths   NaN  2,400sq.ft.             NaN  5.7Cr
#
#     Area_Type
# 782  PlotArea

# %%
house1 = house.drop(['index'],axis=1)
house1
# Out:
#                                     Location Bedrooms     Baths   Total_sqft  \
# 0           2 BHK Apartment in Maruthi Nagar       2    2 Baths    959sq.ft.
# 1      3 BHK Apartment in 3rd Phase JP Nagar       3    3 Baths  2,280sq.ft.
# 2     11 Bedroom House in 8th Phase JP Nagar      11   11 Baths  1,200sq.ft.
# 3          3 BHK Apartment in CV Raman Nagar       3    3 Baths  2,189sq.ft.
# 4          2 BHK Apartment in CV Raman Nagar       2    2 Baths  1,165sq.ft.
# ...                                      ...      ...       ...          ...
# 1653          3 BHK Apartment in Nehru Nagar       3    2 Baths  1,275sq.ft.
# 1654        2 BHK Apartment in Sarjapur Road       2    2 Baths  1,049sq.ft.
# 1655   2 BHK Apartment in Addischetan Layout       2    2 Baths  1,000sq.ft.
# 1656              2 Bedroom House in Kengeri       2     1 Bath    650sq.ft.
# 1657        3 Bedroom House in Kaggadasapura       3    4 Baths    900sq.ft.
#
#      Price_per_sqft   Price      Area_Type
# ...

# %%
house1.describe(include='all').T
# Out:
#                count unique                                 top freq
# Location        1658   1103  2 BHK Apartment in Electronic City   22
# Bedrooms        1658     17                                  2   713
# Baths           1657     16                             2 Baths  874
# Total_sqft      1658    632                         1,200sq.ft.  159
# Price_per_sqft  1658   1216                               5,000   22
# Price           1658    288                                 70L   55
# Area_Type       1658      4                       Superbuilt-up  572
